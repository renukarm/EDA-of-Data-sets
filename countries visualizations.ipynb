# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r'C:\Users\mssre\Desktop\datas\world report.csv',"\t")
df.head()
# Out:
#    S.No Country name                  Regional indicator  Ladder score  \
# 0   1.0  Afghanistan                          South Asia         2.523
# 1   2.0      Albania          Central and Eastern Europe         5.117
# 2   3.0      Algeria        Middle East and North Africa         4.887
# 3   4.0    Argentina         Latin America and Caribbean         5.929
# 4   5.0      Armenia  Commonwealth of Independent States         5.283
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.038         2.596         2.449
# 1                           0.059         5.234         5.001
# 2                           0.053         4.991         4.783
# 3                           0.056         6.040         5.819
# 4                           0.058         5.397         5.168
#
#    Logged GDP per capita  Social support  Healthy life expectancy  ...  \
# 0                  7.695           0.463                   52.493  ...
# ...

# %%
#data cleaning
df.dropna(inplace=True)
print(df.isna().sum())
print(df.duplicated().sum())
# Out:
# S.No                                          0
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# ...

# %%
#data visualization, classifying off of GDP
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.scatterplot(y="Logged GDP per capita",x="Country name",data=df,hue="Logged GDP per capita")
plt.xticks(rotation=90,size=4)
plt.legend(bbox_to_anchor=(1.05,1),loc=2)
plt.show()

# %%
#data visualization, top 10 of everything
def top10(value):
    return df[value].sort_values(ascending=False).iloc[0:10]
cols=df.columns
for name in cols:
    print("The tabele is of",name,", here it is:",top10(name))
# Out:
# The tabele is of S.No , here it is: 148    149.0
# 147    148.0
# 146    147.0
# 145    146.0
# 144    145.0
# 143    144.0
# 142    143.0
# 141    142.0
# 140    141.0
# 139    140.0
# Name: S.No, dtype: float64
# The tabele is of Country name , here it is: 148                Zimbabwe
# 147                  Zambia
# 146                   Yemen
# 145                 Vietnam
# 144               Venezuela
# 143              Uzbekistan
# 142                 Uruguay
# 141           United States
# 140          United Kingdom
# 139    United Arab Emirates
# Name: Country name, dtype: object
# The tabele is of Regional indicator , here it is: 96     Western Europe
# 11     Western Europe
# 31     Western Europe
# 78     Western Europe
# 45     Western Europe
# 33     Western Europe
# 101    Western Europe
# 103    Western Europe
# 111    Western Europe
# 59     Western Europe
# Name: Regional indicator, dtype: object
# The tabele is of Ladder score , here it is: 40     7.842
# ...

# %%
bols=df.columns
new_df=df.drop(bols[14:21],axis=1)
new=new_df.drop(["Standard error of ladder score","upperwhisker","lowerwhisker"],axis=1)
happs=new.columns
print(happs)
print(new.shape)
# Out:
# Index(['S.No', 'Country name', 'Regional indicator', 'Ladder score',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia'],
#       dtype='object')
# (149, 11)

# %%
#all visualizations in one code
happs=new.columns
gud=[]
for j in happs:
    gud.append(j)
print(gud)
guds=gud[3:12]
print(guds)

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

def vas(rix):
    l=new[rix].mean()
    return new[new[rix]>=l].sort_values(rix,ascending=False)
for h in guds:
    sns.lineplot(x="Country name",y=h,data=vas(h))
    plt.title(h)
    plt.xticks(rotation=90,size=5)
    plt.show()
    sns.lineplot(x="Regional indicator",y=h,data=vas(h))
    plt.title(h)
    plt.xticks(rotation=90)
    plt.show()
    print("Details of top happy mean places according to **",h,"** are: ",vas(h))
# Out:
# ['S.No', 'Country name', 'Regional indicator', 'Ladder score', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'Ladder score in Dystopia']
# ['Ladder score', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'Ladder score in Dystopia']
# Details of top happy mean places according to ** Ladder score ** are:        S.No        Country name                  Regional indicator  \
# 40    41.0             Finland                      Western Europe
# 33    34.0             Denmark                      Western Europe
# 128  129.0         Switzerland                      Western Europe
# 54    55.0             Iceland                      Western Europe
# 96    97.0         Netherlands                      Western Europe
# ..     ...                 ...                                 ...
# ...
